# %% [markdown]
# # modelling all file

# %%
import os
import pandas as pd
import numpy as np
import time
import joblib as jb
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.model_selection import StratifiedKFold
pd.set_option('display.max_colwidth',2000)
pd.set_option('display.max_columns', 2000)

# %%
start = time.time()
f1_ = []
recall_ = []
std_dev_f1 = []
std_dev_recall = []
files_ = []
directory = "labeled_data\\"
for root,dirs,files in os.walk(directory):
    for file in files:
        if file.endswith(".csv"):
            print()
            print("-----------------------------------------")
            print()
            print("File no:", file)
            print()
            
            #reading the csv
            data = pd.read_csv(directory+file)
            #Applying log transormation on the numerical features
            data['followers'] = np.log1p(data["followers"])
            data["listed_count"] = np.log1p(data["listed_count"])
            data['Avg_favorites_per_post'] = np.log1p(data["Avg_favorites_per_post"])
            data['listed_follower_ratio'] = np.log1p(data["listed_follower_ratio"])
            data['follower-following_ratio'] =  np.log1p(data["follower-following_ratio"])
            
            #Encoding categorical features
            tweet_type = pd.get_dummies(data.tweet_type)
            data = pd.concat([data,tweet_type], axis = "columns")
            
            #Creating target and independent variable
            data = data.reindex(columns=['followers','listed_count','Avg_favorites_per_post','follower-following_ratio','listed_follower_ratio','Positive tweet','Negative tweet','target'])
            X = data.iloc[ : , :7]
            y = data.target
            
            cv = StratifiedKFold(n_splits= 10)
            
            w0 = len(X) / (2 * y.value_counts()[0])
            w1 =  len(X) / (2 * y.value_counts()[1])
            
            class_weight = {0:w0,1:w1}

            # Number of trees in random forest
            n_estimators = [int(x) for x in np.linspace(20,100, num = 5)]
            # Maximum number of levels in tree
            max_depth = [int(x) for x in np.linspace(20,100, num = 5)]
            max_depth.append(None)
            bootstrap = [True, False]
            criterion = ['entropy','gini']

            # Create the random grid
            random_grid = {'n_estimators': n_estimators,
                           'max_depth': max_depth,
                           'bootstrap': bootstrap,
                           'criterion' : criterion
                           }
            
            scores = ['f1_macro', 'recall_macro']
            model =  RandomForestClassifier(class_weight =class_weight)
            rf_random = GridSearchCV(estimator = model, param_grid  = random_grid,verbose=2, cv = cv,  n_jobs = -1,scoring = scores,refit='f1_macro')
            rf_random.fit(X, y)
            paramter = rf_random.best_params_
            
            f1_scores = []
            recall_scores = []

            for train_index,test_index in cv.split(X,y):
                X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index],y.iloc[test_index]

                w0 = len(X) / (2 * y_train.value_counts()[0])
                w1 =  len(X) / (2 * y_train.value_counts()[1])

                class_weight = {0:w0,1:w1}
                model = RandomForestClassifier(n_estimators = paramter['n_estimators'], max_depth = paramter['max_depth'], class_weight =class_weight,bootstrap = paramter['bootstrap'],criterion = paramter['criterion'])
                model.fit(X_train,y_train)
                y_pred = model.predict(X_test)
                f1_scores.append(f1_score(y_test,y_pred, average = 'macro',labels=np.unique(y_pred)))
                recall_scores.append(recall_score(y_pred,y_test,average = 'macro',labels=np.unique(y_pred)))
                
            f1_.append(round(np.mean(f1_scores),4))
            recall_.append(round(np.mean(recall_scores),4))
            std_dev_f1.append(round(np.std(f1_scores),4))
            std_dev_recall.append(round(np.std(recall_scores),4))
            
            print("F1 score:", round(np.mean(f1_scores),4))
            print("Std dev of F1 score:",round(np.std(f1_scores),4))
            print("Recall:", round(np.mean(recall_scores),4))
            print("Std dev of Recall:", round(np.std(recall_scores),4))
            
            file = file.split('.')
            file = file[0].split("_")
            file = file[1] + "_" + file[2]
            path = "saved_model\\" + file
            jb.dump(model, path)
            files_.append(file)
            

result = pd.DataFrame(
    {'dataset' : files_,
     'F1-score': f1_,
     'recall': recall_,
     'std_dev_f1':std_dev_f1,
     'std_dev_recall' : std_dev_recall
    })

folder = 'result\\'
result.to_csv(folder + 'result.csv', index = False)

end = time.time()
print()
print("=================================")
print("Total Time Taken:",end - start)
print("=================================")
print()
print("=============================")
print("Average F1-score:", round(np.mean(f1_),4))
print("Max F1-score:",round(np.max(f1_),4))
print("Min F1-score:",round(np.min(f1_),4))
print("Average Recall:", round(np.mean(recall_),4))
print("Max Recall:",round(np.max(recall_),4))
print("Min Recall:",round(np.min(recall_),4))
print("=============================")
# Out:
# -----------------------------------------
#
# File no: cleaned_topic_1.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7409
# Std dev of F1 score: 0.0509
# Recall: 0.7861
# Std dev of Recall: 0.0642
#
# -----------------------------------------
#
# File no: cleaned_topic_10.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.722
# Std dev of F1 score: 0.0292
# Recall: 0.7482
# Std dev of Recall: 0.0227
#
# -----------------------------------------
#
# File no: cleaned_topic_100.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7536
# Std dev of F1 score: 0.1118
# Recall: 0.7874
# Std dev of Recall: 0.1201
#
# -----------------------------------------
#
# File no: cleaned_topic_11.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7013
# Std dev of F1 score: 0.0629
# Recall: 0.7547
# Std dev of Recall: 0.0711
#
# -----------------------------------------
#
# File no: cleaned_topic_12.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7684
# Std dev of F1 score: 0.0158
# Recall: 0.7804
# Std dev of Recall: 0.0175
#
# -----------------------------------------
#
# File no: cleaned_topic_13.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7188
# Std dev of F1 score: 0.0699
# Recall: 0.7294
# Std dev of Recall: 0.0672
#
# -----------------------------------------
#
# File no: cleaned_topic_14.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7554
# Std dev of F1 score: 0.0477
# Recall: 0.7798
# Std dev of Recall: 0.046
#
# -----------------------------------------
#
# File no: cleaned_topic_15.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7615
# Std dev of F1 score: 0.0357
# Recall: 0.7707
# Std dev of Recall: 0.0402
#
# -----------------------------------------
#
# File no: cleaned_topic_16.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7281
# Std dev of F1 score: 0.0303
# Recall: 0.7866
# Std dev of Recall: 0.0622
#
# -----------------------------------------
#
# File no: cleaned_topic_17.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.6966
# Std dev of F1 score: 0.1076
# Recall: 0.7465
# Std dev of Recall: 0.1085
#
# -----------------------------------------
#
# File no: cleaned_topic_18.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7424
# Std dev of F1 score: 0.0469
# Recall: 0.7908
# Std dev of Recall: 0.0677
#
# -----------------------------------------
#
# File no: cleaned_topic_19.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7266
# Std dev of F1 score: 0.0839
# Recall: 0.7936
# Std dev of Recall: 0.0947
#
# -----------------------------------------
#
# File no: cleaned_topic_2.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.6808
# Std dev of F1 score: 0.045
# Recall: 0.7029
# Std dev of Recall: 0.0413
#
# -----------------------------------------
#
# File no: cleaned_topic_20.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7219
# Std dev of F1 score: 0.0898
# Recall: 0.772
# Std dev of Recall: 0.0822
#
# -----------------------------------------
#
# File no: cleaned_topic_21.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7199
# Std dev of F1 score: 0.0417
# Recall: 0.7558
# Std dev of Recall: 0.0425
#
# -----------------------------------------
#
# File no: cleaned_topic_22.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7059
# Std dev of F1 score: 0.0232
# Recall: 0.7325
# Std dev of Recall: 0.0317
#
# -----------------------------------------
#
# File no: cleaned_topic_23.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7763
# Std dev of F1 score: 0.047
# Recall: 0.785
# Std dev of Recall: 0.0381
#
# -----------------------------------------
#
# File no: cleaned_topic_24.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.6973
# Std dev of F1 score: 0.0599
# Recall: 0.7201
# Std dev of Recall: 0.0685
#
# -----------------------------------------
#
# File no: cleaned_topic_25.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7575
# Std dev of F1 score: 0.035
# Recall: 0.7587
# Std dev of Recall: 0.0369
#
# -----------------------------------------
#
# File no: cleaned_topic_26.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.8266
# Std dev of F1 score: 0.0596
# Recall: 0.8479
# Std dev of Recall: 0.0787
#
# -----------------------------------------
#
# File no: cleaned_topic_27.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7161
# Std dev of F1 score: 0.0275
# Recall: 0.7368
# Std dev of Recall: 0.0412
#
# -----------------------------------------
#
# File no: cleaned_topic_28.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7066
# Std dev of F1 score: 0.0699
# Recall: 0.7398
# Std dev of Recall: 0.066
#
# -----------------------------------------
#
# File no: cleaned_topic_29.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7267
# Std dev of F1 score: 0.1186
# Recall: 0.7591
# Std dev of Recall: 0.1222
#
# -----------------------------------------
#
# File no: cleaned_topic_3.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7455
# Std dev of F1 score: 0.0706
# Recall: 0.7685
# Std dev of Recall: 0.0637
#
# -----------------------------------------
#
# File no: cleaned_topic_30.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.6973
# Std dev of F1 score: 0.0893
# Recall: 0.7202
# Std dev of Recall: 0.0941
#
# -----------------------------------------
#
# File no: cleaned_topic_31.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7115
# Std dev of F1 score: 0.0544
# Recall: 0.7544
# Std dev of Recall: 0.0803
#
# -----------------------------------------
#
# File no: cleaned_topic_32.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7109
# Std dev of F1 score: 0.0192
# Recall: 0.7517
# Std dev of Recall: 0.0366
#
# -----------------------------------------
#
# File no: cleaned_topic_33.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7345
# Std dev of F1 score: 0.0625
# Recall: 0.7487
# Std dev of Recall: 0.0705
#
# -----------------------------------------
#
# File no: cleaned_topic_34.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7178
# Std dev of F1 score: 0.0411
# Recall: 0.7383
# Std dev of Recall: 0.0381
#
# -----------------------------------------
#
# File no: cleaned_topic_35.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.764
# Std dev of F1 score: 0.0827
# Recall: 0.7919
# Std dev of Recall: 0.0647
#
# -----------------------------------------
#
# File no: cleaned_topic_36.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.6873
# Std dev of F1 score: 0.0531
# Recall: 0.7129
# Std dev of Recall: 0.0438
#
# -----------------------------------------
#
# File no: cleaned_topic_37.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.9205
# Std dev of F1 score: 0.0189
# Recall: 0.9322
# Std dev of Recall: 0.0153
#
# -----------------------------------------
#
# File no: cleaned_topic_38.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7246
# Std dev of F1 score: 0.0232
# Recall: 0.7427
# Std dev of Recall: 0.0214
#
# -----------------------------------------
#
# File no: cleaned_topic_39.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.6875
# Std dev of F1 score: 0.0497
# Recall: 0.6909
# Std dev of Recall: 0.0513
#
# -----------------------------------------
#
# File no: cleaned_topic_4.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7639
# Std dev of F1 score: 0.0398
# Recall: 0.7999
# Std dev of Recall: 0.0527
#
# -----------------------------------------
#
# File no: cleaned_topic_40.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7651
# Std dev of F1 score: 0.067
# Recall: 0.7874
# Std dev of Recall: 0.0807
#
# -----------------------------------------
#
# File no: cleaned_topic_41.csv
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7828
# Std dev of F1 score: 0.0223
# Recall: 0.8008
# Std dev of Recall: 0.023
#
# -----------------------------------------
#
# File no: cleaned_topic_42.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7048
# Std dev of F1 score: 0.08
# Recall: 0.7395
# Std dev of Recall: 0.0786
#
# -----------------------------------------
#
# File no: cleaned_topic_43.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7104
# Std dev of F1 score: 0.051
# Recall: 0.7229
# Std dev of Recall: 0.0488
#
# -----------------------------------------
#
# File no: cleaned_topic_44.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7585
# Std dev of F1 score: 0.0147
# Recall: 0.7798
# Std dev of Recall: 0.0153
#
# -----------------------------------------
#
# File no: cleaned_topic_45.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7568
# Std dev of F1 score: 0.015
# Recall: 0.7833
# Std dev of Recall: 0.0156
#
# -----------------------------------------
#
# File no: cleaned_topic_46.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7419
# Std dev of F1 score: 0.026
# Recall: 0.7835
# Std dev of Recall: 0.0184
#
# -----------------------------------------
#
# File no: cleaned_topic_47.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7209
# Std dev of F1 score: 0.0337
# Recall: 0.7624
# Std dev of Recall: 0.0333
#
# -----------------------------------------
#
# File no: cleaned_topic_48.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7637
# Std dev of F1 score: 0.0186
# Recall: 0.7864
# Std dev of Recall: 0.0192
#
# -----------------------------------------
#
# File no: cleaned_topic_49.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7504
# Std dev of F1 score: 0.0268
# Recall: 0.7822
# Std dev of Recall: 0.0177
#
# -----------------------------------------
#
# File no: cleaned_topic_5.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.8017
# Std dev of F1 score: 0.0523
# Recall: 0.8404
# Std dev of Recall: 0.041
#
# -----------------------------------------
#
# File no: cleaned_topic_50.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7886
# Std dev of F1 score: 0.0937
# Recall: 0.8598
# Std dev of Recall: 0.065
#
# -----------------------------------------
#
# File no: cleaned_topic_51.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7587
# Std dev of F1 score: 0.0137
# Recall: 0.7831
# Std dev of Recall: 0.0138
#
# -----------------------------------------
#
# File no: cleaned_topic_52.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.783
# Std dev of F1 score: 0.023
# Recall: 0.8125
# Std dev of Recall: 0.0219
#
# -----------------------------------------
#
# File no: cleaned_topic_53.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7559
# Std dev of F1 score: 0.0209
# Recall: 0.784
# Std dev of Recall: 0.02
#
# -----------------------------------------
#
# File no: cleaned_topic_54.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7467
# Std dev of F1 score: 0.0216
# Recall: 0.7779
# Std dev of Recall: 0.0134
#
# -----------------------------------------
#
# File no: cleaned_topic_55.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7818
# Std dev of F1 score: 0.025
# Recall: 0.8045
# Std dev of Recall: 0.03
#
# -----------------------------------------
#
# File no: cleaned_topic_56.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7395
# Std dev of F1 score: 0.0481
# Recall: 0.7615
# Std dev of Recall: 0.0452
#
# -----------------------------------------
#
# File no: cleaned_topic_57.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7193
# Std dev of F1 score: 0.0771
# Recall: 0.7419
# Std dev of Recall: 0.0654
#
# -----------------------------------------
#
# File no: cleaned_topic_58.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.754
# Std dev of F1 score: 0.0888
# Recall: 0.829
# Std dev of Recall: 0.0891
#
# -----------------------------------------
#
# File no: cleaned_topic_59.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.6907
# Std dev of F1 score: 0.0561
# Recall: 0.7439
# Std dev of Recall: 0.0662
#
# -----------------------------------------
#
# File no: cleaned_topic_6.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.8111
# Std dev of F1 score: 0.0602
# Recall: 0.8892
# Std dev of Recall: 0.0548
#
# -----------------------------------------
#
# File no: cleaned_topic_60.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7641
# Std dev of F1 score: 0.0395
# Recall: 0.8008
# Std dev of Recall: 0.0458
#
# -----------------------------------------
#
# File no: cleaned_topic_61.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7732
# Std dev of F1 score: 0.0438
# Recall: 0.8044
# Std dev of Recall: 0.0505
#
# -----------------------------------------
#
# File no: cleaned_topic_62.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7131
# Std dev of F1 score: 0.051
# Recall: 0.7573
# Std dev of Recall: 0.0584
#
# -----------------------------------------
#
# File no: cleaned_topic_63.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7783
# Std dev of F1 score: 0.0383
# Recall: 0.7964
# Std dev of Recall: 0.0452
#
# -----------------------------------------
#
# File no: cleaned_topic_64.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7525
# Std dev of F1 score: 0.0701
# Recall: 0.7639
# Std dev of Recall: 0.07
#
# -----------------------------------------
#
# File no: cleaned_topic_65.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7338
# Std dev of F1 score: 0.0305
# Recall: 0.7583
# Std dev of Recall: 0.0355
#
# -----------------------------------------
#
# File no: cleaned_topic_66.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7487
# Std dev of F1 score: 0.054
# Recall: 0.7726
# Std dev of Recall: 0.0532
#
# -----------------------------------------
#
# File no: cleaned_topic_67.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.6854
# Std dev of F1 score: 0.0439
# Recall: 0.7034
# Std dev of Recall: 0.0586
#
# -----------------------------------------
#
# File no: cleaned_topic_68.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7048
# Std dev of F1 score: 0.0371
# Recall: 0.7071
# Std dev of Recall: 0.0412
#
# -----------------------------------------
#
# File no: cleaned_topic_69.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7003
# Std dev of F1 score: 0.0448
# Recall: 0.7336
# Std dev of Recall: 0.0648
#
# -----------------------------------------
#
# File no: cleaned_topic_7.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7057
# Std dev of F1 score: 0.0307
# Recall: 0.7278
# Std dev of Recall: 0.0469
#
# -----------------------------------------
#
# File no: cleaned_topic_70.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.8472
# Std dev of F1 score: 0.0609
# Recall: 0.8859
# Std dev of Recall: 0.0814
#
# -----------------------------------------
#
# File no: cleaned_topic_71.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7694
# Std dev of F1 score: 0.071
# Recall: 0.8184
# Std dev of Recall: 0.0872
#
# -----------------------------------------
#
# File no: cleaned_topic_72.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7305
# Std dev of F1 score: 0.0571
# Recall: 0.7378
# Std dev of Recall: 0.059
#
# -----------------------------------------
#
# File no: cleaned_topic_73.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7319
# Std dev of F1 score: 0.0381
# Recall: 0.7523
# Std dev of Recall: 0.0414
#
# -----------------------------------------
#
# File no: cleaned_topic_74.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7663
# Std dev of F1 score: 0.1383
# Recall: 0.7733
# Std dev of Recall: 0.1301
#
# -----------------------------------------
#
# File no: cleaned_topic_75.csv
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7185
# Std dev of F1 score: 0.0561
# Recall: 0.7857
# Std dev of Recall: 0.0791
#
# -----------------------------------------
#
# File no: cleaned_topic_76.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.8139
# Std dev of F1 score: 0.0834
# Recall: 0.8264
# Std dev of Recall: 0.091
#
# -----------------------------------------
#
# File no: cleaned_topic_77.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.755
# Std dev of F1 score: 0.0691
# Recall: 0.813
# Std dev of Recall: 0.074
#
# -----------------------------------------
#
# File no: cleaned_topic_78.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7647
# Std dev of F1 score: 0.0582
# Recall: 0.8148
# Std dev of Recall: 0.0599
#
# -----------------------------------------
#
# File no: cleaned_topic_79.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7724
# Std dev of F1 score: 0.0627
# Recall: 0.8232
# Std dev of Recall: 0.067
#
# -----------------------------------------
#
# File no: cleaned_topic_8.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7351
# Std dev of F1 score: 0.0879
# Recall: 0.7541
# Std dev of Recall: 0.0827
#
# -----------------------------------------
#
# File no: cleaned_topic_80.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7888
# Std dev of F1 score: 0.0522
# Recall: 0.7964
# Std dev of Recall: 0.0511
#
# -----------------------------------------
#
# File no: cleaned_topic_81.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7514
# Std dev of F1 score: 0.0459
# Recall: 0.7812
# Std dev of Recall: 0.0416
#
# -----------------------------------------
#
# File no: cleaned_topic_82.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.789
# Std dev of F1 score: 0.0428
# Recall: 0.8092
# Std dev of Recall: 0.0471
#
# -----------------------------------------
#
# File no: cleaned_topic_83.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.6978
# Std dev of F1 score: 0.0483
# Recall: 0.7415
# Std dev of Recall: 0.0635
#
# -----------------------------------------
#
# File no: cleaned_topic_84.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7627
# Std dev of F1 score: 0.0765
# Recall: 0.7821
# Std dev of Recall: 0.0697
#
# -----------------------------------------
#
# File no: cleaned_topic_85.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.71
# Std dev of F1 score: 0.0475
# Recall: 0.7266
# Std dev of Recall: 0.0483
#
# -----------------------------------------
#
# File no: cleaned_topic_86.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.69
# Std dev of F1 score: 0.0478
# Recall: 0.7579
# Std dev of Recall: 0.0452
#
# -----------------------------------------
#
# File no: cleaned_topic_87.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7522
# Std dev of F1 score: 0.0494
# Recall: 0.7967
# Std dev of Recall: 0.0571
#
# -----------------------------------------
#
# File no: cleaned_topic_88.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7024
# Std dev of F1 score: 0.04
# Recall: 0.7188
# Std dev of Recall: 0.0354
#
# -----------------------------------------
#
# File no: cleaned_topic_89.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.742
# Std dev of F1 score: 0.1133
# Recall: 0.7622
# Std dev of Recall: 0.1108
#
# -----------------------------------------
#
# File no: cleaned_topic_9.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7504
# Std dev of F1 score: 0.0315
# Recall: 0.7689
# Std dev of Recall: 0.0323
#
# -----------------------------------------
#
# File no: cleaned_topic_90.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7519
# Std dev of F1 score: 0.0665
# Recall: 0.7776
# Std dev of Recall: 0.0409
#
# -----------------------------------------
#
# File no: cleaned_topic_91.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.8457
# Std dev of F1 score: 0.0547
# Recall: 0.8328
# Std dev of Recall: 0.067
#
# -----------------------------------------
#
# File no: cleaned_topic_92.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.6797
# Std dev of F1 score: 0.0474
# Recall: 0.7191
# Std dev of Recall: 0.0415
#
# -----------------------------------------
#
# File no: cleaned_topic_93.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7173
# Std dev of F1 score: 0.0518
# Recall: 0.7202
# Std dev of Recall: 0.0564
#
# -----------------------------------------
#
# File no: cleaned_topic_94.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7133
# Std dev of F1 score: 0.1138
# Recall: 0.7288
# Std dev of Recall: 0.1202
#
# -----------------------------------------
#
# File no: cleaned_topic_95.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7205
# Std dev of F1 score: 0.0453
# Recall: 0.7377
# Std dev of Recall: 0.0365
#
# -----------------------------------------
#
# File no: cleaned_topic_96.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.6871
# Std dev of F1 score: 0.071
# Recall: 0.7127
# Std dev of Recall: 0.0884
#
# -----------------------------------------
#
# File no: cleaned_topic_97.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7183
# Std dev of F1 score: 0.0351
# Recall: 0.7394
# Std dev of Recall: 0.0372
#
# -----------------------------------------
#
# File no: cleaned_topic_98.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.8246
# Std dev of F1 score: 0.0807
# Recall: 0.8402
# Std dev of Recall: 0.0728
#
# -----------------------------------------
#
# File no: cleaned_topic_99.csv
#
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# F1 score: 0.7074
# Std dev of F1 score: 0.0336
# Recall: 0.7238
# Std dev of Recall: 0.033
#
# =================================
# Total Time Taken: 18223.2677154541
# =================================
#
# =============================
# Average F1-score: 0.7427
# Max F1-score: 0.9205
# Min F1-score: 0.6797
# Average Recall: 0.7716
# Max Recall: 0.9322
# Min Recall: 0.6909
# =============================
